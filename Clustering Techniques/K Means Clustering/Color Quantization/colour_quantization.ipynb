# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The following library helps us convert .jpg,.png to numpy arrays

# %%
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread('F:\\hard_disk\\New folder\\Machine_Learning\\K_means_clustering\\palm_trees.jpg')

# %%
#image_as_array

# %%
image_as_array.shape
# Out:
# (1401, 934, 3)

# %%
plt.imshow(image_as_array)

# %% [markdown]
# image_as_array is a 3D array which needs to be converted to a 2D one

# %%
(h,w,c) =  image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
image_as_array2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=8)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[200, 155, 101],
#        [  3,   2,   3],
#        [ 58,  98, 130],
#        [227, 138,  41],
#        [153, 149, 140],
#        [ 57,  55,  58],
#        [ 99, 128, 147],
#        [151,  97,  59]])

# %%
quantized_image = np.reshape(rgb_codes[labels],(h,w,c))

# %%
plt.imshow(quantized_image)
